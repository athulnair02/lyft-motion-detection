# %% [markdown]
# <a href="https://colab.research.google.com/github/athulnair02/lyft-motion-detection/blob/master/LyftProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lyft Motion Prediction for Automation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pwd
import os
#os.chdir('drive/My Drive/Colab Notebooks/Kaggle_Lyft_Competition/Data')
#dir = os.listdir('drive/My Drive/Colab Notebooks/Kaggle_Lyft_Competition/Data')
#print(dir)
# !unzip lyft-motion-prediction-autonomous-vehicles.zip
# !pwd
#/My Drive/Colab Notebook/Kaggle_Lyft_Competition/Data

#!kaggle competitions download -c lyft-motion-prediction-autonomous-vehicles
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: scenes/train.zarr/agents/14963
#   inflating: scenes/train.zarr/agents/14964
#   inflating: scenes/train.zarr/agents/14965
#   inflating: scenes/train.zarr/agents/14966
#   inflating: scenes/train.zarr/agents/14967
#   inflating: scenes/train.zarr/agents/14968
#   inflating: scenes/train.zarr/agents/14969
#   inflating: scenes/train.zarr/agents/1497
#   inflating: scenes/train.zarr/agents/14970
#   inflating: scenes/train.zarr/agents/14971
#   inflating: scenes/train.zarr/agents/14972
#   inflating: scenes/train.zarr/agents/14973
#   inflating: scenes/train.zarr/agents/14974
#   inflating: scenes/train.zarr/agents/14975
#   inflating: scenes/train.zarr/agents/14976
#   inflating: scenes/train.zarr/agents/14977
#   inflating: scenes/train.zarr/agents/14978
#   inflating: scenes/train.zarr/agents/14979
#   inflating: scenes/train.zarr/agents/1498
#   inflating: scenes/train.zarr/agents/14980
# ...

# %%
import os
dir = os.listdir('drive/My Drive/Kaggle_Lyft_Competition')
dir
# Out:
# ['LyftProject.ipynb', 'Data']
